# %% [markdown]
# 드라이브연결

# %%
# Google Drive와 연결
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 압축파일 풀어주는 코드 작성

# %%
# %cd /content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터(제주도 및 도서지역)/01-1.정식개방데이터/Validation/01.원천데이터

# !unzip -qq "/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터(제주도 및 도서지역)/01-1.정식개방데이터/Validation/01.원천데이터/VS_csv.zip"
# Out:
# /content/drive/.shortcut-targets-by-id/1hjJIOvf8vjK3R9tUzSphUXcFw1DhWHj7/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터(제주도 및 도서지역)/01-1.정식개방데이터/Validation/01.원천데이터
# ...

# %%
import zipfile
zip_file = zipfile.ZipFile('/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터(제주도 및 도서지역)/01-1.정식개방데이터/Validation/01.원천데이터/VS_csv.zip') # 압축을 해제할 '/파일경로/파일명.zip'
zip_file.extractall('/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터(제주도 및 도서지역)/01-1.정식개방데이터/Validation/01.원천데이터') # 압축을 해제할 '/위치경로/'
