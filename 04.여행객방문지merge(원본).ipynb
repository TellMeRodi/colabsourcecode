# %% [markdown]
# # import 및 drive 연결

# %%
# Google Drive와 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 데이터 불러오기

# %%
visit = pd.read_csv('/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/001.권역별데이터(원본)/Training/방문지정보.csv')
traveler = pd.read_csv('/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/002.권역별데이터(MBTI예측)/여행객(MBTI예측).csv')

# %% [markdown]
# # merge

# %%
visit['TRAVEL_ID'] = visit['TRAVEL_ID'].str[2:]
merge = pd.merge(traveler, visit, left_on='TRAVELER_ID', right_on='TRAVEL_ID', how='inner')
merge
# Out:
#       TRAVELER_ID  RESIDENCE_SGG_CD GENDER  AGE_GRP  EDU_NM  EDU_FNSH_SE  \
# 0         a006685                41      여       30       5          1.0
# 1         a006685                41      여       30       5          1.0
# 2         a006685                41      여       30       5          1.0
# 3         a006685                41      여       30       5          1.0
# 4         a006685                41      여       30       5          1.0
# ...           ...               ...    ...      ...     ...          ...
# 38275     d000216                11      여       30       7          1.0
# 38276     d000216                11      여       30       7          1.0
# 38277     d000216                11      여       30       7          1.0
# 38278     d000216                11      여       30       7          1.0
# 38279     d000216                11      여       30       7          1.0
#
#        MARR_STTS  FAMILY_MEMB  JOB_NM  JOB_ETC  ...              POI_NM  \
# ...

# %% [markdown]
# # csv추출

# %%
merge.to_csv(f'/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/003.여행객방문지merge(원본)/여행객방문지.csv', index=False)
