# %% [markdown]
# # import 및 drive 연결

# %%
# Google Drive와 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# ## Training

# %%
base_path = '/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터'
base_path2 = '01-1.정식개방데이터/Training/01.원천데이터/TS_csv'
activityconsume_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_activity_consume_his_활동소비내역_A.csv')
activityconsume_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_activity_consume_his_활동소비내역_B.csv')
activityconsume_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_activity_consume_his_활동소비내역_C.csv')
activityconsume_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_activity_consume_his_활동소비내역_D.csv')
activityhis_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_activity_his_활동내역_A.csv')
activityhis_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_activity_his_활동내역_B.csv')
activityhis_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_activity_his_활동내역_C.csv')
activityhis_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_activity_his_활동내역_D.csv')
advconsumehis_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_adv_consume_his_사전소비내역_A.csv')
advconsumehis_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_adv_consume_his_사전소비내역_B.csv')
advconsumehis_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_adv_consume_his_사전소비내역_C.csv')
advconsumehis_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_adv_consume_his_사전소비내역_D.csv')
companioninfo_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_companion_info_동반자정보_A.csv')
companioninfo_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_companion_info_동반자정보_B.csv')
companioninfo_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_companion_info_동반자정보_C.csv')
companioninfo_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_companion_info_동반자정보_D.csv')
lodgeconsumehis_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_lodge_consume_his_숙박소비내역_A.csv')
lodgeconsumehis_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_lodge_consume_his_숙박소비내역_B.csv')
lodgeconsumehis_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_lodge_consume_his_숙박소비내역_C.csv')
lodgeconsumehis_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_lodge_consume_his_숙박소비내역_D.csv')
movehis_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_move_his_이동내역_A.csv')
movehis_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_move_his_이동내역_B.csv')
movehis_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_move_his_이동내역_C.csv')
movehis_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_move_his_이동내역_D.csv')
mvmnconsumehis_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_mvmn_consume_his_이동수단소비내역_A.csv')
mvmnconsumehis_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_mvmn_consume_his_이동수단소비내역_B.csv')
mvmnconsumehis_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_mvmn_consume_his_이동수단소비내역_C.csv')
mvmnconsumehis_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_mvmn_consume_his_이동수단소비내역_D.csv')
travel_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_travel_여행_A.csv')
travel_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_travel_여행_B.csv')
travel_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_travel_여행_C.csv')
travel_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_travel_여행_D.csv')
traveler_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_traveller_master_여행객 Master_A.csv')
traveler_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_traveller_master_여행객 Master_B.csv')
traveler_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_traveller_master_여행객 Master_C.csv')
traveler_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_traveller_master_여행객 Master_D.csv')
visitareainfo_A_training = pd.read_csv(f'{base_path}(수도권)/{base_path2}/tn_visit_area_info_방문지정보_A.csv')
visitareainfo_B_training = pd.read_csv(f'{base_path}(동부권)/{base_path2}/tn_visit_area_info_방문지정보_B.csv')
visitareainfo_C_training = pd.read_csv(f'{base_path}(서부권)/{base_path2}/tn_visit_area_info_방문지정보_C.csv')
visitareainfo_D_training = pd.read_csv(f'{base_path}(제주도 및 도서지역)/{base_path2}/tn_visit_area_info_방문지정보_D.csv')

# %% [markdown]
# ## Validation

# %%
base_path3 = '/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/000.국내 여행로그 데이터'
base_path4 = '01-1.정식개방데이터/Validation/01.원천데이터/VS_csv'
activityconsume_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_activity_consume_his_활동소비내역_A.csv')
activityconsume_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_activity_consume_his_활동소비내역_B.csv')
activityconsume_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_activity_consume_his_활동소비내역_C.csv')
activityconsume_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_activity_consume_his_활동소비내역_D.csv')
activityhis_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_activity_his_활동내역_A.csv')
activityhis_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_activity_his_활동내역_B.csv')
activityhis_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_activity_his_활동내역_C.csv')
activityhis_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_activity_his_활동내역_D.csv')
advconsumehis_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_adv_consume_his_사전소비내역_A.csv')
advconsumehis_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_adv_consume_his_사전소비내역_B.csv')
advconsumehis_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_adv_consume_his_사전소비내역_C.csv')
advconsumehis_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_adv_consume_his_사전소비내역_D.csv')
companioninfo_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_companion_info_동반자정보_A.csv')
companioninfo_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_companion_info_동반자정보_B.csv')
companioninfo_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_companion_info_동반자정보_C.csv')
companioninfo_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_companion_info_동반자정보_D.csv')
lodgeconsumehis_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_lodge_consume_his_숙박소비내역_A.csv')
lodgeconsumehis_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_lodge_consume_his_숙박소비내역_B.csv')
lodgeconsumehis_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_lodge_consume_his_숙박소비내역_C.csv')
lodgeconsumehis_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_lodge_consume_his_숙박소비내역_D.csv')
movehis_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_move_his_이동내역_A.csv')
movehis_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_move_his_이동내역_B.csv')
movehis_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_move_his_이동내역_C.csv')
movehis_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_move_his_이동내역_D.csv')
mvmnconsumehis_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_mvmn_consume_his_이동수단소비내역_A.csv')
mvmnconsumehis_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_mvmn_consume_his_이동수단소비내역_B.csv')
mvmnconsumehis_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_mvmn_consume_his_이동수단소비내역_C.csv')
mvmnconsumehis_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_mvmn_consume_his_이동수단소비내역_D.csv')
travel_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_travel_여행_A.csv')
travel_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_travel_여행_B.csv')
travel_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_travel_여행_C.csv')
travel_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_travel_여행_D.csv')
traveler_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_traveller_master_여행객 Master_A.csv')
traveler_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_traveller_master_여행객 Master_B.csv')
traveler_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_traveller_master_여행객 Master_C.csv')
traveler_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_traveller_master_여행객 Master_D.csv')
visitareainfo_A_validation = pd.read_csv(f'{base_path3}(수도권)/{base_path4}/tn_visit_area_info_방문지정보_A.csv')
visitareainfo_B_validation = pd.read_csv(f'{base_path3}(동부권)/{base_path4}/tn_visit_area_info_방문지정보_B.csv')
visitareainfo_C_validation = pd.read_csv(f'{base_path3}(서부권)/{base_path4}/tn_visit_area_info_방문지정보_C.csv')
visitareainfo_D_validation = pd.read_csv(f'{base_path3}(제주도 및 도서지역)/{base_path4}/tn_visit_area_info_방문지정보_D.csv')

# %% [markdown]
# # merge

# %% [markdown]
# ## Training

# %%
activityconsume_training = pd.concat([activityconsume_A_training, activityconsume_B_training, activityconsume_C_training, activityconsume_D_training], axis=0, ignore_index=True)
activityhis_training = pd.concat([activityhis_A_training, activityhis_B_training, activityhis_C_training, activityhis_D_training], axis=0, ignore_index=True)
advconsumehis_training = pd.concat([advconsumehis_A_training, advconsumehis_B_training, advconsumehis_C_training, advconsumehis_D_training], axis=0, ignore_index=True)
companioninfo_training = pd.concat([companioninfo_A_training, companioninfo_B_training, companioninfo_C_training, companioninfo_D_training], axis=0, ignore_index=True)
lodgeconsumehis_training = pd.concat([lodgeconsumehis_A_training, lodgeconsumehis_B_training, lodgeconsumehis_C_training, lodgeconsumehis_D_training], axis=0, ignore_index=True)
movehis_training = pd.concat([movehis_A_training, movehis_B_training, movehis_C_training, movehis_D_training], axis=0, ignore_index=True)
mvmnconsumehis_training = pd.concat([mvmnconsumehis_A_training, mvmnconsumehis_B_training, mvmnconsumehis_C_training, mvmnconsumehis_D_training], axis=0, ignore_index=True)
travel_training = pd.concat([travel_A_training, travel_B_training, travel_C_training, travel_D_training], axis=0, ignore_index=True)
traveler_training = pd.concat([traveler_A_training, traveler_B_training, traveler_C_training, traveler_D_training], axis=0, ignore_index=True)
visitareainfo_training = pd.concat([visitareainfo_A_training, visitareainfo_B_training, visitareainfo_C_training, visitareainfo_D_training], axis=0, ignore_index=True)

# %% [markdown]
# ## Validation

# %%
activityconsume_validation = pd.concat([activityconsume_A_validation, activityconsume_B_validation, activityconsume_C_validation, activityconsume_D_validation], axis=0, ignore_index=True)
activityhis_validation = pd.concat([activityhis_A_validation, activityhis_B_validation, activityhis_C_validation, activityhis_D_validation], axis=0, ignore_index=True)
advconsumehis_validation = pd.concat([advconsumehis_A_validation, advconsumehis_B_validation, advconsumehis_C_validation, advconsumehis_D_validation], axis=0, ignore_index=True)
companioninfo_validation = pd.concat([companioninfo_A_validation, companioninfo_B_validation, companioninfo_C_validation, companioninfo_D_validation], axis=0, ignore_index=True)
lodgeconsumehis_validation = pd.concat([lodgeconsumehis_A_validation, lodgeconsumehis_B_validation, lodgeconsumehis_C_validation, lodgeconsumehis_D_validation], axis=0, ignore_index=True)
movehis_validation = pd.concat([movehis_A_validation, movehis_B_validation, movehis_C_validation, movehis_D_validation], axis=0, ignore_index=True)
mvmnconsumehis_validation = pd.concat([mvmnconsumehis_A_validation, mvmnconsumehis_B_validation, mvmnconsumehis_C_validation, mvmnconsumehis_D_validation], axis=0, ignore_index=True)
travel_validation = pd.concat([travel_A_validation, travel_B_validation, travel_C_validation, travel_D_validation], axis=0, ignore_index=True)
traveler_validation = pd.concat([traveler_A_validation, traveler_B_validation, traveler_C_validation, traveler_D_validation], axis=0, ignore_index=True)
visitareainfo_validation = pd.concat([visitareainfo_A_validation, visitareainfo_B_validation, visitareainfo_C_validation, visitareainfo_D_validation], axis=0, ignore_index=True)

# %% [markdown]
# # csv추출

# %% [markdown]
# ## Training

# %%
datalist = [activityconsume_training, activityhis_training, advconsumehis_training, companioninfo_training, lodgeconsumehis_training,
            movehis_training, mvmnconsumehis_training, travel_training, traveler_training, visitareainfo_training]
filelist = ['활동소비내역', '활동내역', '사전소비내역', '동반자정보', '숙박소비내역', '이동내역', '이동수단소비내역', '여행', '여행객', '방문지정보']
for idx in range(len(filelist)) :
  datalist[idx].to_csv(f'/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/001.권역별데이터(원본)/Training/{filelist[idx]}.csv', index=False)

# %% [markdown]
# ## Validation

# %%
datalist = [activityconsume_validation, activityhis_validation, advconsumehis_validation, companioninfo_validation, lodgeconsumehis_validation,
            movehis_validation, mvmnconsumehis_validation, travel_validation, traveler_validation, visitareainfo_validation]
filelist = ['활동소비내역', '활동내역', '사전소비내역', '동반자정보', '숙박소비내역', '이동내역', '이동수단소비내역', '여행', '여행객', '방문지정보']
for idx in range(len(filelist)) :
  datalist[idx].to_csv(f'/content/drive/MyDrive/3조(Rodi알려조)/9. 데이터셋/001.권역별데이터(원본)/Validation/{filelist[idx]}.csv', index=False)
